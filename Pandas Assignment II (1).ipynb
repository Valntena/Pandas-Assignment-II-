# %%
import pandas as pd
import numpy as np

# %%
PATH_URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"

# Save column names as a list
col_ls = ["age", "workclass", "education","education-num","marital-status", "occupation", "relationship", "sex", "race", "ing-fishing", "capital-gain" 
         , "capital-loss" , "hours-per-week" , "native-country"]

# Pass in col_ls into names parameter to explicitly name each column
df_adult = pd.read_csv(PATH_URL, names=col_ls, index_col=False)
df_adult.head()
# Out:
#    age          workclass  education education-num  marital-status  \
# 0   39          State-gov      77516     Bachelors              13
# 1   50   Self-emp-not-inc      83311     Bachelors              13
# 2   38            Private     215646       HS-grad               9
# 3   53            Private     234721          11th               7
# 4   28            Private     338409     Bachelors              13
#
#             occupation        relationship             sex    race  \
# 0        Never-married        Adm-clerical   Not-in-family   White
# 1   Married-civ-spouse     Exec-managerial         Husband   White
# 2             Divorced   Handlers-cleaners   Not-in-family   White
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4   Married-civ-spouse      Prof-specialty            Wife   Black
#
#   ing-fishing  capital-gain  capital-loss  hours-per-week  native-country
# 0        Male          2174             0              40   United-States
# ...

# %%
#Look at the DataFrame shape

df_adult.shape
# Out:
# (32561, 14)

# %%
#head

df_adult.head()
# Out:
#    age          workclass  education education-num  marital-status  \
# 0   39          State-gov      77516     Bachelors              13
# 1   50   Self-emp-not-inc      83311     Bachelors              13
# 2   38            Private     215646       HS-grad               9
# 3   53            Private     234721          11th               7
# 4   28            Private     338409     Bachelors              13
#
#             occupation        relationship             sex    race  \
# 0        Never-married        Adm-clerical   Not-in-family   White
# 1   Married-civ-spouse     Exec-managerial         Husband   White
# 2             Divorced   Handlers-cleaners   Not-in-family   White
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4   Married-civ-spouse      Prof-specialty            Wife   Black
#
#   ing-fishing  capital-gain  capital-loss  hours-per-week  native-country
# 0        Male          2174             0              40   United-States
# ...

# %%
# tail
df_adult.tail()
# Out:
#        age      workclass  education education-num  marital-status  \
# 32556   27        Private     257302    Assoc-acdm              12
# 32557   40        Private     154374       HS-grad               9
# 32558   58        Private     151910       HS-grad               9
# 32559   22        Private     201490       HS-grad               9
# 32560   52   Self-emp-inc     287927       HS-grad               9
#
#                 occupation        relationship         sex    race  \
# 32556   Married-civ-spouse        Tech-support        Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct     Husband   White
# 32558              Widowed        Adm-clerical   Unmarried   White
# 32559        Never-married        Adm-clerical   Own-child   White
# 32560   Married-civ-spouse     Exec-managerial        Wife   White
#
#       ing-fishing  capital-gain  capital-loss  hours-per-week  native-country
# 32556      Female             0             0              38   United-States
# ...

# %%
# describe all numerical features

df_adult.describe()
# Out:
#                 age     education  marital-status  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04    32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05       10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05        2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04        1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05        9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05       10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05       12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06       16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#

df_adult.describe(include='all')
# Out:
#                  age workclass     education education-num  marital-status  \
# count   32561.000000     32561  3.256100e+04         32561    32561.000000
# unique           NaN         9           NaN            16             NaN
# top              NaN   Private           NaN       HS-grad             NaN
# freq             NaN     22696           NaN         10501             NaN
# mean       38.581647       NaN  1.897784e+05           NaN       10.080679
# std        13.640433       NaN  1.055500e+05           NaN        2.572720
# min        17.000000       NaN  1.228500e+04           NaN        1.000000
# 25%        28.000000       NaN  1.178270e+05           NaN        9.000000
# 50%        37.000000       NaN  1.783560e+05           NaN       10.000000
# 75%        48.000000       NaN  2.370510e+05           NaN       12.000000
# max        90.000000       NaN  1.484705e+06           NaN       16.000000
#
# ...

# %%
# mean for all numerical columns

print(df_adult.mean())
# Out:
# age                   38.581647
# education         189778.366512
# marital-status        10.080679
# capital-gain        1077.648844
# capital-loss          87.303830
# hours-per-week        40.437456
# dtype: float64

# %%
# median for all numerical columns

print(df_adult.median())
# Out:
# age                   37.0
# education         178356.0
# marital-status        10.0
# capital-gain           0.0
# capital-loss           0.0
# hours-per-week        40.0
# dtype: float64

# %%
# mode for all numerical columns

df_adult.mode(numeric_only=True)
# Out:
#     age  education  marital-status  capital-gain  capital-loss  hours-per-week
# 0  36.0     123011             9.0           0.0           0.0            40.0
# 1   NaN     164190             NaN           NaN           NaN             NaN
# 2   NaN     203488             NaN           NaN           NaN             NaN

# %%
# standard deviation for all numerical columns

df_adult.std()
# Out:
# age                   13.640433
# education         105549.977697
# marital-status         2.572720
# capital-gain        7385.292085
# capital-loss         402.960219
# hours-per-week        12.347429
# dtype: float64

# %%
# sum for all numerical columns
sum_column = df_adult.sum(axis=0)
print (sum_column)
# Out:
# 6220206594

# %%
# count for all column

df_adult.count()
# Out:
# age               32561
# workclass         32561
# education         32561
# education-num     32561
# marital-status    32561
# occupation        32561
# relationship      32561
# sex               32561
# race              32561
# ing-fishing       32561
# capital-gain      32561
# capital-loss      32561
# hours-per-week    32561
# native-country    32561
# dtype: int64

# %%
#How many missing values are in each column
df_adult.isnull().sum()
# Out:
# age               0
# workclass         0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# race              0
# ing-fishing       0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# dtype: int64

# %%
#value_counts for all categorical columns
df_adult.value_counts()
# Out:
# 6179373392    1
# 1256257       1
# 1316684       1
# 35089324      1
# 328237        1
# 2842700       1
# dtype: int64

# %%
#Subset your DataFrame based on one condition
above_35 = df_adult[df_adult["age"] > 35]

# %%
above_35.head()
# Out:
#    age          workclass  education education-num  marital-status  \
# 0   39          State-gov      77516     Bachelors              13
# 1   50   Self-emp-not-inc      83311     Bachelors              13
# 2   38            Private     215646       HS-grad               9
# 3   53            Private     234721          11th               7
# 5   37            Private     284582       Masters              14
#
#             occupation        relationship             sex    race  \
# 0        Never-married        Adm-clerical   Not-in-family   White
# 1   Married-civ-spouse     Exec-managerial         Husband   White
# 2             Divorced   Handlers-cleaners   Not-in-family   White
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black
# 5   Married-civ-spouse     Exec-managerial            Wife   White
#
#   ing-fishing  capital-gain  capital-loss  hours-per-week  native-country
# 0        Male          2174             0              40   United-States
# ...

# %%
race_sex = df_adult[["age", "race"]]

# %%
race_sex.head()
# Out:
#    age    race
# 0   39   White
# 1   50   White
# 2   38   White
# 3   53   Black
# 4   28   Black

# %%
#Subset your DataFrame based on two different conditions

age = df_adult[(df_adult["age"] == 37) | (df_adult["age"] == 40)]

# %%
age.head()
# Out:
#     age workclass  education  education-num  marital-status  \
# 5    37   Private     284582        Masters              14
# 10   37   Private     280464   Some-college              10
# 14   40   Private     121772      Assoc-voc              11
# 20   40   Private     193524      Doctorate              16
# 76   40   Private      32214     Assoc-acdm              12
#
#              occupation      relationship       sex                 race  \
# 5    Married-civ-spouse   Exec-managerial      Wife                White
# 10   Married-civ-spouse   Exec-managerial   Husband                Black
# 14   Married-civ-spouse      Craft-repair   Husband   Asian-Pac-Islander
# 20   Married-civ-spouse    Prof-specialty   Husband                White
# 76   Married-civ-spouse      Adm-clerical   Husband                White
#
#    ing-fishing  capital-gain  capital-loss  hours-per-week  native-country
# 5       Female             0             0              40   United-States
# ...

# %%
## Subset your DataFrame based on three different conditions
age2 = df_adult[(df_adult["age"] == 37) | (df_adult["age"] == 40) | (df_adult["age"] == 28)]

# %%
age2.head()
# Out:
#     age workclass  education  education-num  marital-status  \
# 4    28   Private     338409      Bachelors              13
# 5    37   Private     284582        Masters              14
# 10   37   Private     280464   Some-college              10
# 14   40   Private     121772      Assoc-voc              11
# 20   40   Private     193524      Doctorate              16
#
#              occupation      relationship       sex                 race  \
# 4    Married-civ-spouse    Prof-specialty      Wife                Black
# 5    Married-civ-spouse   Exec-managerial      Wife                White
# 10   Married-civ-spouse   Exec-managerial   Husband                Black
# 14   Married-civ-spouse      Craft-repair   Husband   Asian-Pac-Islander
# 20   Married-civ-spouse    Prof-specialty   Husband                White
#
#    ing-fishing  capital-gain  capital-loss  hours-per-week  native-country
# 4       Female             0             0              40            Cuba
# ...

# %%
#Use loc to slice your DataFrame for the 2 columns that returned the largest sum
df_adult.iloc[1:5,2:4]
# Out:
#    education education-num
# 1      83311     Bachelors
# 2     215646       HS-grad
# 3     234721          11th
# 4     338409     Bachelors
